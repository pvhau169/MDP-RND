# %%
import numpy as np
import gym
from QRND import QRND
import matplotlib.pyplot as plt
import torch

# %%
real_return_PATH = 'log/real_return.txt'
combined_return_return_PATH = 'log/combined_return.txt'


real_return = np.loadtxt(real_return_PATH)
combined_return = np.loadtxt(combined_return_return_PATH)

# %%
def smooth(y, box_pts):
    box = np.ones(box_pts)/box_pts
    y_smooth = np.convolve(y, box, mode='valid')
#     y_smooth[0] = y[0]
    return y_smooth

# %%
Y_combined[0]
# Out:
# 58.01593020558357

# %%
invertal = 5


Y_real = real_return.copy()
Y_smooth_real = smooth(Y_real,invertal)

Y_combined = combined_return.copy()
Y_smooth_combined = smooth(Y_combined,invertal)

Y_intrinsic = Y_combined - Y_real
Y_intrinsic_combined = smooth(Y_intrinsic,invertal)

x = np.linspace(0, len(Y_smooth_real), len(Y_smooth_real))
fig1 = plt.figure()
ax1 = plt.axes()
ax1.plot(x, Y_smooth_real, 'r-', lw=2, label = "extrinsic reward")
ax1.plot(x, Y_intrinsic_combined, 'g-', lw=2, label = "intrinsic reward")
ax1.plot(x, Y_smooth_combined, 'b-', lw=2, label = "combined reward")
ax1.legend()
ax1.set_xlabel("epochs")
ax1.set_ylabel("average rewards")



# Y2 = smooth(Y)
# x = np.linspace(0, len(Y), len(Y))
# fig2 = plt.figure()
# ax2 = plt.axes()
# ax2.plot(x, Y, Y2)

# obs = env.reset()
# for t in range(1000):
#     env.render()
#     x = torch.Tensor(obs).unsqueeze(0)
#     Q = alg.model(x)
#     action = Q.argmax().detach().item()
#     new_obs, reward, done, info = env.step(action)
#     obs = new_obs
#     if done:
#         break
# Out:
# Text(0, 0.5, 'average rewards')

# %%
real_return_PATH = 'log/real_return_grid_world_1.txt'
combined_return_return_PATH = 'log/combined_return_grid_world_1.txt'


real_return = np.loadtxt(real_return_PATH)[:7000]
combined_return = np.loadtxt(combined_return_return_PATH)[:7000]

# %%
invertal = 100


Y_real = real_return.copy()
Y_smooth_real = smooth(Y_real,invertal)

Y_combined = combined_return.copy()
Y_smooth_combined = smooth(Y_combined,invertal)

Y_intrinsic = Y_combined - Y_real
Y_intrinsic_combined = smooth(Y_intrinsic,invertal)

x = np.linspace(0, len(Y_smooth_real), len(Y_smooth_real))
fig1 = plt.figure()
ax1 = plt.axes()
ax1.plot(x, Y_smooth_real, 'r-', lw=2, label = "extrinsic reward")
ax1.plot(x, Y_intrinsic_combined, 'g-', lw=2, label = "intrinsic reward")
ax1.plot(x, Y_smooth_combined, 'b-', lw=2, label = "combined reward")
ax1.legend()
ax1.set_xlabel("epochs")
ax1.set_ylabel("average rewards")
# Out:
# Text(0, 0.5, 'average rewards')

# %%
env = gym.make('gridworld-v0')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\qqwea1223\appdata\local\programs\python\python37\lib\site-packages\gym\envs\registration.py in spec(self, path)
#     120         try:
# --> 121             return self.env_specs[id]
#     122         except KeyError:
#
# KeyError: 'gridworld-v0'
#
# During handling of the above exception, another exception occurred:
#
# UnregisteredEnv                           Traceback (most recent call last)
# <ipython-input-64-dd9e84beb22e> in <module>
# ----> 1 env = gym.make('gridworld-v0')
#
# c:\users\qqwea1223\appdata\local\programs\python\python37\lib\site-packages\gym\envs\registration.py in make(id, **kwargs)
#     143
#     144 def make(id, **kwargs):
# --> 145     return registry.make(id, **kwargs)
#     146
#     147 def spec(id):
#
# ...

# %%
env.action_space
# Out:
# Discrete(5)

# %%
env.grid_map_path
# Out:
# 'D:\\UD\\MPC-RDN\\mountainCar\\MountainCar_DQN_RND\\gym_gridworld\\envs\\plan5.txt'

# %%
with open(grid_map_path, 'r') as f:
    grid_map = f.readlines()
    try:
        grid_map_array = np.array(list(map( lambda x: list(map(lambda y: int(y),x.split(' '))), grid_map)))
    except:
        print(grid_map)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-80-ae1b6360338b> in <module>
# ----> 1 with open(grid_map_path, 'r') as f:
#       2     grid_map = f.readlines()
#       3     try:
#       4         grid_map_array = np.array(list(map( lambda x: list(map(lambda y: int(y),x.split(' '))), grid_map)))
#       5     except:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'plan1.txt'

# %%
grid_map_path
# Out:
# 'plan1.txt'

# %%
a = np.array(grid_map)
a.shape
# Out:
# (16,)

# %%
x = a[0]
b = int('1\n')
b
# Out:
# 1

# %%
import numpy as np
import gym
from QRND import QRND, NeuralNet
import matplotlib.pyplot as plt
import torch
import gym_gridworld


env_gridworld = gym.make('gridworld-v0')
env_mountain_car = gym.make('MountainCar-v0')

# %%
state_grid = env_gridworld.reset()

# %%
actions = env_gridworld.action_space
observations = env_gridworld.observation_space

# %%
actions_mountain = env_mountain_car.action_space
observations_mountain = env_mountain_car.observation_space

# %%
model = NeuralNet(observations.shape[0], actions.n, 64)
b_model = NeuralNet(observations_mountain.shape[0], actions_mountain.n, 64)

# %%
state_grid
# Out:
# [3, 3]

# %%
state_mountain = env_mountain_car.reset()
state_mountain
# Out:
# array([-0.40469343,  0.        ])

# %%
torch.Tensor(state_mountain).unsqueeze(0)
# Out:
# tensor([[-0.4775,  0.0000]])

# %%
state_mountain
# Out:
# array([-0.4774688,  0.       ])

# %%
b_model = Neural
# Out:
# tensor([[3., 3.]])

# %%
b = b_model(torch.Tensor(state_mountain).unsqueeze(0))

# %%
state_grid_temp = torch.Tensor(state_grid).unsqueeze(0)
a = model(state_grid_temp)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-20-ecbb08e9795b> in <module>
#       1 state_grid_temp = torch.Tensor(state_grid).unsqueeze(0)
# ----> 2 a = model(state_grid_temp)
#
# c:\users\qqwea1223\appdata\local\programs\python\python37\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# D:\UD\auddition_code\Q_learning_RND\QRND.py in forward(self, x)
#      25
#      26         def forward(self, x):
# ---> 27                 x = torch.nn.functional.relu(self.layer1(x))
#      28                 # x = torch.nn.functional.relu(self.layer2(x))
# ...

# %%
state_grid_temp
# Out:
# tensor([[3., 3.]])

# %%
torch.Tensor(state_mountain).unsqueeze(0)
# Out:
# tensor([[-0.4047,  0.0000]])
