# %%
import numpy as np
import gym
from dqn_rnd import DQN_RND
import matplotlib.pyplot as plt
from smooth_signal import smooth
import torch

# %%
real_return_PATH = 'log/real_return.txt'
combined_return_return_PATH = 'log/combined_return.txt'


real_return = np.loadtxt(real_return_PATH)
combined_return = np.loadtxt(combined_return_return_PATH)

# %%
Y = real_return.copy()
Y2 = smooth(Y)
x = np.linspace(0, len(Y), len(Y))
fig1 = plt.figure()
ax1 = plt.axes()
ax1.plot(x, Y, Y2)

Y=combined_return.copy()
# Y = np.asarray(log.get_log('combined_return'))
Y2 = smooth(Y)
x = np.linspace(0, len(Y), len(Y))
fig2 = plt.figure()
ax2 = plt.axes()
ax2.plot(x, Y, Y2)

# obs = env.reset()
# for t in range(1000):
#     env.render()
#     x = torch.Tensor(obs).unsqueeze(0)
#     Q = alg.model(x)
#     action = Q.argmax().detach().item()
#     new_obs, reward, done, info = env.step(action)
#     obs = new_obs
#     if done:
#         break
# Out:
# [<matplotlib.lines.Line2D at 0x1f905e4b908>,
#  <matplotlib.lines.Line2D at 0x1f905e83c48>]

# %%
import numpy as np
import gym
import gym_gridworld
from dqn_rnd import DQN_RND
import matplotlib.pyplot as plt
from smooth_signal import smooth
import torch


# env = gym.make('gridworld-v0')

# %%
env = gym.make('gridworld-v0')
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: Start or target state not specified

# %%
env.action_space
# Out:
# Discrete(5)

# %%
env.grid_map_path
# Out:
# 'D:\\UD\\MPC-RDN\\mountainCar\\MountainCar_DQN_RND\\gym_gridworld\\envs\\plan5.txt'

# %%
with open(grid_map_path, 'r') as f:
    grid_map = f.readlines()
    try:
        grid_map_array = np.array(list(map( lambda x: list(map(lambda y: int(y),x.split(' '))), grid_map)))
    except:
        print(grid_map)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-80-ae1b6360338b> in <module>
# ----> 1 with open(grid_map_path, 'r') as f:
#       2     grid_map = f.readlines()
#       3     try:
#       4         grid_map_array = np.array(list(map( lambda x: list(map(lambda y: int(y),x.split(' '))), grid_map)))
#       5     except:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'plan1.txt'

# %%
grid_map_path
# Out:
# 'plan1.txt'

# %%
a = np.array(grid_map)
a.shape
# Out:
# (16,)

# %%
x = a[0]
b = int('1\n')
b
# Out:
# 1

# %%
import numpy as np
import gym
from QRND import QRND
import matplotlib.pyplot as plt
import torch
import gym_gridworld


env = gym.make('gridworld-v0')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-b4e1355398d0> in <module>
#       1 import numpy as np
#       2 import gym
# ----> 3 from QRND import QRND
#       4 import matplotlib.pyplot as plt
#       5 import torch
#
# ModuleNotFoundError: No module named 'QRND'
